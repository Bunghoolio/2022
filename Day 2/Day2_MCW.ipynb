# %%
import numpy as np
import pandas as pd
import math

# %%
df_rps = pd.read_csv('StrategyGuide.txt', header = None, sep = ' ',names = ['Opponent Play','Should Play'])
df_rps2 = pd.read_csv('StrategyGuide.txt', header = None, sep = ' ',names = ['Opponent Play','Round Result'])

print(df_rps)
# Out:
#      Opponent Play Should Play
# 0                B           Z
# 1                B           Z
# 2                B           Y
# 3                C           Y
# 4                B           Y
# ...            ...         ...
# 2495             B           Y
# 2496             C           Y
# 2497             B           Z
# 2498             A           Y
# 2499             C           Y
#
# [2500 rows x 2 columns]

# %%
df_rps = df_rps.replace(['A','B','C','X','Y','Z'], ['rock','paper','scissor','rock','paper','scissor'])

# %%
df_rps
# Out:
#      Opponent Play Should Play
# 0            paper     scissor
# 1            paper     scissor
# 2            paper       paper
# 3          scissor       paper
# 4            paper       paper
# ...            ...         ...
# 2495         paper       paper
# 2496       scissor       paper
# 2497         paper     scissor
# 2498          rock       paper
# 2499       scissor       paper
#
# [2500 rows x 2 columns]

# %%
for row in df_rps.itertuples(index = False):
    print(row[0],row[1])
# Out:
# paper scissor
# paper scissor
# paper paper
# scissor paper
# paper paper
# scissor paper
# scissor paper
# rock scissor
# paper paper
# rock paper
# scissor rock
# rock paper
# rock paper
# scissor paper
# rock paper
# paper paper
# paper paper
# scissor paper
# rock paper
# rock paper
# rock paper
# scissor paper
# rock paper
# paper paper
# rock paper
# paper paper
# scissor paper
# paper rock
# rock rock
# rock paper
# scissor rock
# paper paper
# scissor paper
# paper paper
# paper rock
# scissor rock
# paper paper
# paper paper
# rock paper
# rock rock
# rock rock
# rock paper
# paper paper
# scissor paper
# scissor rock
# rock rock
# paper paper
# scissor scissor
# paper paper
# scissor rock
# rock paper
# rock rock
# scissor rock
# rock paper
# rock paper
# rock paper
# rock paper
# paper rock
# scissor paper
# scissor scissor
# paper paper
# scissor paper
# rock paper
# rock paper
# paper paper
# rock paper
# scissor rock
# paper paper
# scissor paper
# scissor paper
# ...

# %%
def play_score(value):
	if value == 'rock':
		return 1
	elif value == 'paper':
		return 2
	elif value == 'scissor':
		return 3


df_rps['play_score'] = df_rps['Should Play'].map(play_score)
display(df_rps.head())
# Out:
#   Opponent Play Should Play  play_score
# 0         paper     scissor           3
# 1         paper     scissor           3
# 2         paper       paper           2
# 3       scissor       paper           2
# 4         paper       paper           2

# %%
conditions = [
    ((df_rps['Opponent Play'] == 'rock') & (df_rps['Should Play'] == 'paper')),
    ((df_rps['Opponent Play'] == 'rock') & (df_rps['Should Play'] == 'scissor')),
    ((df_rps['Opponent Play'] =='rock') & (df_rps['Should Play'] == 'rock')),

    ((df_rps['Opponent Play'] == 'paper') & (df_rps['Should Play'] == 'scissor')),
    ((df_rps['Opponent Play'] == 'paper') & (df_rps['Should Play'] == 'rock')),
    ((df_rps['Opponent Play'] =='paper') & (df_rps['Should Play'] == 'paper')),

    ((df_rps['Opponent Play'] == 'scissor') & (df_rps['Should Play'] == 'rock')),
    ((df_rps['Opponent Play'] == 'scissor') & (df_rps['Should Play'] == 'paper')),
    ((df_rps['Opponent Play'] =='scissor') & (df_rps['Should Play'] == 'scissor'))
    ]


values = ['win', 'loss', 'draw','win', 'loss', 'draw','win', 'loss', 'draw']


df_rps['outcome'] = np.select(conditions, values)


print(df_rps)
# Out:
#      Opponent Play Should Play  play_score outcome
# 0            paper     scissor           3     win
# 1            paper     scissor           3     win
# 2            paper       paper           2    draw
# 3          scissor       paper           2    loss
# 4            paper       paper           2    draw
# ...            ...         ...         ...     ...
# 2495         paper       paper           2    draw
# 2496       scissor       paper           2    loss
# 2497         paper     scissor           3     win
# 2498          rock       paper           2     win
# 2499       scissor       paper           2    loss
#
# [2500 rows x 4 columns]

# %%
def win_score(value):
    if value == 'win':
        return 6
    if value == 'draw':
        return 3
    if value == 'loss':
        return 0

df_rps['win_score'] = df_rps['outcome'].map(win_score)

# %%
df_rps['total_score'] = df_rps['play_score'] + df_rps['win_score']

# %%
print(df_rps)
# Out:
#      Opponent Play Should Play  play_score outcome  win_score  total_score
# 0            paper     scissor           3     win          6            9
# 1            paper     scissor           3     win          6            9
# 2            paper       paper           2    draw          3            5
# 3          scissor       paper           2    loss          0            2
# 4            paper       paper           2    draw          3            5
# ...            ...         ...         ...     ...        ...          ...
# 2495         paper       paper           2    draw          3            5
# 2496       scissor       paper           2    loss          0            2
# 2497         paper     scissor           3     win          6            9
# 2498          rock       paper           2     win          6            8
# 2499       scissor       paper           2    loss          0            2
#
# [2500 rows x 6 columns]

# %%
sum(df_rps['total_score'])
# Out:
# 13005

# %%
################### PART 2 OF PROBLEM ####################

print(df_rps2)
# Out:
#      Opponent Play Round Result
# 0                B            Z
# 1                B            Z
# 2                B            Y
# 3                C            Y
# 4                B            Y
# ...            ...          ...
# 2495             B            Y
# 2496             C            Y
# 2497             B            Z
# 2498             A            Y
# 2499             C            Y
#
# [2500 rows x 2 columns]

# %%
df_rps2 = df_rps2.replace(['A','B','C','X','Y','Z'], ['rock','paper','scissor','Loss','Draw','Win'])

# %%
print(df_rps2)
# Out:
#      Opponent Play Round Result
# 0            paper          Win
# 1            paper          Win
# 2            paper         Draw
# 3          scissor         Draw
# 4            paper         Draw
# ...            ...          ...
# 2495         paper         Draw
# 2496       scissor         Draw
# 2497         paper          Win
# 2498          rock         Draw
# 2499       scissor         Draw
#
# [2500 rows x 2 columns]

# %%
df_test = df_rps2.copy()

def test_udf(col):
    if col == 'scissor':
        return 'whatever'

df_test['test'] = df_test['Opponent Play'].apply(lambda x: test_udf(x))

# %%
df_test
# Out:
#      Opponent Play Round Result      test
# 0            paper          Win      None
# 1            paper          Win      None
# 2            paper         Draw      None
# 3          scissor         Draw  whatever
# 4            paper         Draw      None
# ...            ...          ...       ...
# 2495         paper         Draw      None
# 2496       scissor         Draw  whatever
# 2497         paper          Win      None
# 2498          rock         Draw      None
# 2499       scissor         Draw  whatever
#
# [2500 rows x 3 columns]

# %%
for ind in df_rps2:
    if df_rps2['Opponent Play'] == 'paper' & df_rps2['Round Result'] == 'Win':# ( 6 win + 3 scissors) ,
        continue
    elif df_rps2['Opponent Play'] == 'scissor' & df_rps2['Round Result'] == 'Win': # ( 6 win + 1 rock) 
        df_rps2['total_score'] = 7
    elseif df_rps2['Opponent Play'] == 'rock' & df_rps2['Round Result'] == 'Win': # ( 6 win + 2 paper) 
         df_rps2['total_score'] = 8

    elseif df_rps2['Opponent Play'] == 'scissors' & df_rps2['Round Result'] == 'Draw': # ( 3 Draw + 3 scissors) 
        then df_rps2['total_score'] = 6
    elseif df_rps2['Opponent Play'] == 'rock' & df_rps2['Round Result'] == 'Draw': # ( 3 Draw + 1 rock) 
        then df_rps2['total_score'] = 4
    elseif df_rps2['Opponent Play'] == 'paper' & df_rps2['Round Result'] == 'Draw': # ( 3 Draw + 2 paper) 
        then df_rps2['total_score'] = 5

    elseif df_rps2['Opponent Play'] == 'scissors' & df_rps2['Round Result'] == 'Draw': # ( 0 Loss + 1 rock) 
        then df_rps2['total_score'] = 1
    elseif df_rps2['Opponent Play'] == 'rock' & df_rps2['Round Result'] == 'Draw': # ( 0 Loss + 2 paper) 
        then df_rps2['total_score'] = 2
    
    elseif df_rps2['Opponent Play'] == 'paper' & df_rps2['Round Result'] == 'Draw': # ( 0 Loss + 3 scissors) 
        then df_rps2['total_score'] = 3

    else df_rps2['total_score'] = 0
# Out:
#   Cell In [17], line 6
#     elseif df_rps2['Opponent Play'] == 'rock' & df_rps2['Round Result'] == 'Win': # ( 6 win + 2 paper)
#            ^
# SyntaxError: invalid syntax

# %%
conditions = [
        ((df_rps2['Opponent Play'] == 'paper') & (df_rps2['Round Result'] == 'Win')),# ( 6 win + 3 scissors) 
        ((df_rps2['Opponent Play'] == 'scissor') & (df_rps2['Round Result'] == 'Win')), # ( 6 win + 1 rock) 
        ((df_rps2['Opponent Play'] == 'rock') & (df_rps2['Round Result'] == 'Win')), # ( 6 win + 2 paper) 
        
        ((df_rps2['Opponent Play'] == 'scissor') & (df_rps2['Round Result'] == 'Draw')), # ( 3 Draw + 3 scissors) 
        ((df_rps2['Opponent Play'] == 'rock') & (df_rps2['Round Result'] == 'Draw')), # ( 3 Draw + 1 rock) 
        ((df_rps2['Opponent Play'] == 'paper') & (df_rps2['Round Result'] == 'Draw')), # ( 3 Draw + 2 paper) 
        

        ((df_rps2['Opponent Play'] == 'scissor') & (df_rps2['Round Result'] == 'Loss')), # ( 0 Loss + 2 paper) 
        ((df_rps2['Opponent Play'] == 'rock') & (df_rps2['Round Result'] == 'Loss')), # ( 0 Loss + 3 scissors) 
        ((df_rps2['Opponent Play'] == 'paper') & (df_rps2['Round Result'] == 'Loss')) # ( 0 Loss + 1 rock) 
]

values = [9,7,8,6,4,5,2,3,1]

df_rps2['total_score'] = np.select(conditions, values)

# %%
print(df_rps2)
# Out:
#      Opponent Play Round Result  total_score
# 0            paper          Win            9
# 1            paper          Win            9
# 2            paper         Draw            5
# 3          scissor         Draw            6
# 4            paper         Draw            5
# ...            ...          ...          ...
# 2495         paper         Draw            5
# 2496       scissor         Draw            6
# 2497         paper          Win            9
# 2498          rock         Draw            4
# 2499       scissor         Draw            6
#
# [2500 rows x 3 columns]

# %%
sum(df_rps2['total_score'])
# Out:
# 11373

# %%
target is 10116
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Temp\ipykernel_19904\2636837391.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   target is 10116
# C:\Temp\ipykernel_19904\2636837391.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   target is 10116
# C:\Temp\ipykernel_19904\2636837391.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   target is 10116
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 target is 10116
#
# NameError: name 'target' is not defined
