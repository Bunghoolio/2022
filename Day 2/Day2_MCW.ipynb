# %%
import numpy as np
import pandas as pd
import math

# %%
df_rps = pd.read_csv('StrategyGuide.txt', header = None, sep = ' ',names = ['Opponent Play','Should Play'])


print(df_rps)
# Out:
#      Opponent Play Should Play
# 0                B           Z
# 1                B           Z
# 2                B           Y
# 3                C           Y
# 4                B           Y
# ...            ...         ...
# 2495             B           Y
# 2496             C           Y
# 2497             B           Z
# 2498             A           Y
# 2499             C           Y
#
# [2500 rows x 2 columns]

# %%
df_rps = df_rps.replace(['A','B','C','X','Y','Z'], ['rock','paper','scissor','rock','paper','scissor'])

# %%
df_rps
# Out:
#      Opponent Play Should Play
# 0            paper     scissor
# 1            paper     scissor
# 2            paper       paper
# 3          scissor       paper
# 4            paper       paper
# ...            ...         ...
# 2495         paper       paper
# 2496       scissor       paper
# 2497         paper     scissor
# 2498          rock       paper
# 2499       scissor       paper
#
# [2500 rows x 2 columns]

# %%
for row in df_rps.itertuples(index = False):
    print(row[0],row[1])
# Out:
# paper scissor
# paper scissor
# paper paper
# scissor paper
# paper paper
# scissor paper
# scissor paper
# rock scissor
# paper paper
# rock paper
# scissor rock
# rock paper
# rock paper
# scissor paper
# rock paper
# paper paper
# paper paper
# scissor paper
# rock paper
# rock paper
# rock paper
# scissor paper
# rock paper
# paper paper
# rock paper
# paper paper
# scissor paper
# paper rock
# rock rock
# rock paper
# scissor rock
# paper paper
# scissor paper
# paper paper
# paper rock
# scissor rock
# paper paper
# paper paper
# rock paper
# rock rock
# rock rock
# rock paper
# paper paper
# scissor paper
# scissor rock
# rock rock
# paper paper
# scissor scissor
# paper paper
# scissor rock
# rock paper
# rock rock
# scissor rock
# rock paper
# rock paper
# rock paper
# rock paper
# paper rock
# scissor paper
# scissor scissor
# paper paper
# scissor paper
# rock paper
# rock paper
# paper paper
# rock paper
# scissor rock
# paper paper
# scissor paper
# scissor paper
# ...

# %%
def play_score(value):
	if value == 'rock':
		return 1
	elif value == 'paper':
		return 2
	elif value == 'scissor':
		return 3


df_rps['play_score'] = df_rps['Should Play'].map(play_score)
display(df_rps.head())
# Out:
#   Opponent Play Should Play  play_score
# 0         paper     scissor           3
# 1         paper     scissor           3
# 2         paper       paper           2
# 3       scissor       paper           2
# 4         paper       paper           2

# %%
conditions = [
    (df_rps['Opponent Play'] == 'rock' and df_rps['Should Play'] == 'paper'),
    (df_rps['Opponent Play'] == 'rock' and df_rps['Should Play'] == 'scissor'),
    (df_rps['Opponent Play'] =='rock' and df_rps['Should Play'] == 'rock'),

    (df_rps['Opponent Play'] == 'paper' and df_rps['Should Play'] == 'scissor'),
    (df_rps['Opponent Play'] == 'paper' and df_rps['Should Play'] == 'rock'),
    (df_rps['Opponent Play'] =='paper' and df_rps['Should Play'] == 'paper'),

    (df_rps['Opponent Play'] == 'scissor' and df_rps['Should Play'] == 'rock'),
    (df_rps['Opponent Play'] == 'scissor' and df_rps['Should Play'] == 'paper'),
    (df_rps['Opponent Play'] =='scissor' and df_rps['Should Play'] == 'scissor')
    ]


values = ['win', 'loss', 'draw','win', 'loss', 'draw','win', 'loss', 'draw']


df_rps['win_score'] = np.select(conditions, values)


df_rps.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [7], line 2
#       1 conditions = [
# ----> 2     (df_rps['Opponent Play'] == 'rock' and df_rps['Should Play'] == 'paper'),
#       3     (df_rps['Opponent Play'] == 'rock' and df_rps['Should Play'] == 'scissor'),
#       4     (df_rps['Opponent Play'] =='rock' and df_rps['Should Play'] == 'rock'),
#       5
#       6     (df_rps['Opponent Play'] == 'paper' and df_rps['Should Play'] == 'scissor'),
#       7     (df_rps['Opponent Play'] == 'paper' and df_rps['Should Play'] == 'rock'),
#       8     (df_rps['Opponent Play'] =='paper' and df_rps['Should Play'] == 'paper'),
#       9
#      10     (df_rps['Opponent Play'] == 'scissor' and df_rps['Should Play'] == 'rock'),
#      11     (df_rps['Opponent Play'] == 'scissor' and df_rps['Should Play'] == 'paper'),
# ...
